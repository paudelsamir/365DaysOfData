# %%
# !pip install -U langchain langchain-community langchain-ollama mlflow chromadb pandas
# Out:
# Requirement already satisfied: langchain in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (0.3.27)
# Requirement already satisfied: langchain-community in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (0.3.31)
# Requirement already satisfied: langchain-ollama in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (0.3.10)
# Requirement already satisfied: mlflow in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (3.4.0)
# Requirement already satisfied: chromadb in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (1.1.1)
# Requirement already satisfied: pandas in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain) (0.4.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain) (2.12.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: anyio in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.11.0)
# Requirement already satisfied: certifi in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-community) (3.13.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-community) (2.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: ollama<1.0.0,>=0.5.3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from langchain-ollama) (0.6.0)
# Requirement already satisfied: mlflow-skinny==3.4.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (3.4.0)
# Requirement already satisfied: mlflow-tracing==3.4.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (3.4.0)
# Requirement already satisfied: Flask<4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (1.17.0)
# Requirement already satisfied: cryptography<46,>=43.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: fastmcp<3,>=2.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (2.12.4)
# Requirement already satisfied: graphene<4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (3.10.7)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: scipy<2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow) (1.16.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (8.3.0)
# Requirement already satisfied: cloudpickle<4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (0.67.0)
# Requirement already satisfied: fastapi<1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (0.119.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (1.37.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (6.32.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (0.5.3)
# Requirement already satisfied: uvicorn<1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mlflow-skinny==3.4.0->mlflow) (0.37.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: Mako in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=1.14 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from cryptography<46,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (2.41.1)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.4.0->mlflow) (0.48.0)
# Requirement already satisfied: authlib>=1.5.2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastmcp<3,>=2.0.0->mlflow) (1.6.5)
# Requirement already satisfied: cyclopts>=3.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastmcp<3,>=2.0.0->mlflow) (3.24.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastmcp<3,>=2.0.0->mlflow) (1.3.0)
# Requirement already satisfied: mcp<2.0.0,>=1.12.4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastmcp<3,>=2.0.0->mlflow) (1.17.0)
# Requirement already satisfied: openapi-core>=0.19.5 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastmcp<3,>=2.0.0->mlflow) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastmcp<3,>=2.0.0->mlflow) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastmcp<3,>=2.0.0->mlflow) (1.11.0)
# Requirement already satisfied: rich>=13.9.4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from fastmcp<3,>=2.0.0->mlflow) (14.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.4.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (3.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.4.0->mlflow) (0.58b0)
# Requirement already satisfied: six>=1.5 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: sniffio>=1.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: build>=1.0.3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (1.23.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: backoff>=1.10.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: pyproject_hooks in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: pycparser in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: docstring-parser>=0.15 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (1.3.1)
# Requirement already satisfied: docutils in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (0.22.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.27.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: sympy in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: isodate in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.3.4)
# Requirement already satisfied: more-itertools in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (10.8.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.7.2)
# Requirement already satisfied: parse in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (1.20.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.4.4)
# Requirement already satisfied: rfc3339-validator in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (1.12.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: email-validator>=2.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb) (0.35.3)
# Requirement already satisfied: filelock in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.10)
# Requirement already satisfied: shellingham>=1.3.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sam/Github/365DaysOfData/venv/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
import pandas as pd
import mlflow
from langchain.chains import RetrievalQA
from langchain.document_loaders import WebBaseLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_ollama import OllamaLLM, OllamaEmbeddings
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
llm = OllamaLLM(model="llama3.2", temperature=0)
embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %%
loader = WebBaseLoader("https://mlflow.org/docs/latest/index.html")
documents = loader.load()

# %%
# split text into chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(documents)

# %%
# build local vector db 
docsearch = Chroma.from_documents(texts, embeddings)

# %%
# create RAG 
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=docsearch.as_retriever(),
    return_source_documents=True,
)

# %%
def model(input_df: pd.DataFrame):
    results = []
    for _, row in input_df.iterrows():
        query = row["questions"]
        response = qa.invoke(query)
        results.append(response["result"])
    return results

eval_df = pd.DataFrame(
    {
        "questions": [
            "what is mlflow?",
            "how to run mlflow.evaluate()?",
            "how to log_table()?",
            "how to load_table()?",
        ],
    }
)

# %%
# since mlflow.genai metrics use openai endpoints, lets define our own,
from mlflow.models import make_metric

def _avg_length(eval_series):
    return {"avg_length": eval_series.str.len().mean()}


response_length_metric = make_metric(
    eval_fn=_avg_length,
    greater_is_better=True,
)

results = mlflow.evaluate(
    model,
    eval_df,
    model_type="question-answering",
    evaluators="default",
    extra_metrics=[response_length_metric],
    predictions="predictions"
)

print("=== METRICS ===")
print(results.metrics)


## not worked as expected...
# Out:
# 2025/10/14 18:24:49 INFO mlflow.models.evaluation.evaluators.default: Computing model predictions.
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[11], line 13
#       5     return {"avg_length": eval_series.str.len().mean()}
#       8 response_length_metric = make_metric(
#       9     eval_fn=_avg_length,
#      10     greater_is_better=True,
#      11 )
# ---> 13 results = mlflow.evaluate(
#      14     model,
#      15     eval_df,
#      16     model_type="question-answering",
#      17     evaluators="default",
#      18     extra_metrics=[response_length_metric],
#      19     predictions="predictions",  # this is the column in eval_df with model outputs
#      20 )
#      22 print("=== METRICS ===")
#      23 print(results.metrics)
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/models/evaluation/deprecated.py:23, in evaluate(*args, **kwargs)
#      12 if is_databricks_uri(tracking_uri):
#      13     warnings.warn(
#      14         "The `mlflow.evaluate` API has been deprecated as of MLflow 3.0.0. "
#      15         "Please use these new alternatives:\n\n"
#    (...)     21         FutureWarning,
#      22     )
# ---> 23 return model_evaluate(*args, **kwargs)
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/models/evaluation/base.py:1791, in evaluate(model, data, model_type, targets, predictions, dataset_path, feature_names, evaluators, evaluator_config, extra_metrics, custom_artifacts, env_manager, model_config, inference_params, model_id, _called_from_genai_evaluate)
#    1788 predictions_expected_in_model_output = predictions if model is not None else None
#    1790 try:
# -> 1791     evaluate_result = _evaluate(
#    1792         model=model,
#    1793         model_type=model_type,
#    1794         model_id=model_id,
#    1795         dataset=dataset,
#    1796         run_id=run_id,
#    1797         evaluator_name_list=evaluator_name_list,
#    1798         evaluator_name_to_conf_map=evaluator_name_to_conf_map,
#    1799         extra_metrics=extra_metrics,
#    1800         custom_artifacts=custom_artifacts,
#    1801         predictions=predictions_expected_in_model_output,
#    1802         evaluators=evaluators,
#    1803     )
#    1804 finally:
#    1805     if isinstance(model, _ServedPyFuncModel):
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/telemetry/track.py:24, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      21 @functools.wraps(func)
#      22 def wrapper(*args: P.args, **kwargs: P.kwargs) -> R:
#      23     if is_telemetry_disabled() or _is_telemetry_disabled_for_event(event):
# ---> 24         return func(*args, **kwargs)
#      26     success = True
#      27     result = None
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/models/evaluation/base.py:1032, in _evaluate(model, model_type, model_id, dataset, run_id, evaluator_name_list, evaluator_name_to_conf_map, extra_metrics, custom_artifacts, predictions, evaluators)
#    1030 if eval_.evaluator.can_evaluate(model_type=model_type, evaluator_config=eval_.config):
#    1031     with configure_autologging_for_evaluation(enable_tracing=should_enable_tracing):
# -> 1032         eval_result = eval_.evaluator.evaluate(
#    1033             model=model,
#    1034             model_type=model_type,
#    1035             model_id=model_id,
#    1036             dataset=dataset,
#    1037             run_id=run_id,
#    1038             evaluator_config=eval_.config,
#    1039             extra_metrics=extra_metrics,
#    1040             custom_artifacts=custom_artifacts,
#    1041             predictions=predictions,
#    1042         )
#    1044     if eval_result is not None:
#    1045         eval_results.append(eval_result)
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/models/evaluation/default_evaluator.py:947, in BuiltInEvaluator.evaluate(self, model_type, dataset, run_id, evaluator_config, model, extra_metrics, custom_artifacts, predictions, model_id, **kwargs)
#     945 with TempDir() as temp_dir, matplotlib.rc_context(_matplotlib_config):
#     946     self.temp_dir = temp_dir
# --> 947     return self._evaluate(model, extra_metrics, custom_artifacts)
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/models/evaluation/evaluators/default.py:77, in DefaultEvaluator._evaluate(self, model, extra_metrics, custom_artifacts, **kwargs)
#      74 y_true = self.dataset.labels_data
#      76 metrics = self._builtin_metrics() + extra_metrics
# ---> 77 self.evaluate_metrics(
#      78     metrics,
#      79     prediction=y_pred,
#      80     target=self.dataset.labels_data,
#      81     other_output_df=other_model_outputs,
#      82 )
#      83 self.evaluate_and_log_custom_artifacts(custom_artifacts, prediction=y_pred, target=y_true)
#      85 # Log metrics and artifacts
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/models/evaluation/default_evaluator.py:753, in BuiltInEvaluator.evaluate_metrics(self, metrics, prediction, target, other_output_df)
#     749 eval_df = self._get_eval_df(prediction, target)
#     750 metrics = [
#     751     MetricDefinition.from_index_and_metric(i, metric) for i, metric in enumerate(metrics)
#     752 ]
# --> 753 metrics = self._order_metrics(metrics, eval_df, other_output_df)
#     755 self._test_first_row(metrics, eval_df, other_output_df)
#     757 # calculate metrics for the full eval_df
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/models/evaluation/default_evaluator.py:689, in BuiltInEvaluator._order_metrics(self, metrics, eval_df, other_output_df)
#     687     # cant calculate any more metrics
#     688     if not did_append_metric:
# --> 689         self._raise_exception_for_malformed_metrics(
#     690             failed_results, eval_df, other_output_df
#     691         )
#     693     remaining_metrics = pending_metrics
#     695 return self.ordered_metrics
#
# File ~/Github/365DaysOfData/venv/lib/python3.13/site-packages/mlflow/models/evaluation/default_evaluator.py:643, in BuiltInEvaluator._raise_exception_for_malformed_metrics(self, malformed_results, eval_df, other_output_df)
#     637         input_columns.append("targets")
#     639 error_message = self._construct_error_message_for_malformed_metrics(
#     640     malformed_results, input_columns, output_columns
#     641 )
# --> 643 raise MlflowException(error_message, error_code=INVALID_PARAMETER_VALUE)
#
# MlflowException: Error: Metric calculation failed for the following metrics:
# Metric '_avg_length' requires the following:
# - missing columns ['eval_series'] need to be defined or mapped
#
# Below are the existing column names for the input/output data:
# Input Columns: ['questions']
# Output Columns: ['predictions']
#
# To resolve this issue, you may need to:
# - specify any required parameters
# - if you are missing columns, check that there are no circular dependencies among your
# metrics, and you may want to map them to an existing column using the following
# configuration:
# evaluator_config={'col_mapping': {<missing column name>: <existing column name>}}
