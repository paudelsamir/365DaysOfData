# %% [markdown]
# Derivatives help us understand the rate of change of a function, and we use them in gradient descent to optimize model parameters.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2

def f_prime(x):
    return 2*x

x = np.linspace(-10, 10, 400)
y = f(x)
y_prime = f_prime(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='$f(x) = x^2$', color='blue')
plt.plot(x, y_prime, label="$f'(x) = 2x$", color='red', linestyle='--')
plt.title("Function and its Derivative")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Gradient Descent function
def gradient_descent(learning_rate, num_iterations):
    x_current = 10  # Starting point
    x_history = [x_current]
    
    for _ in range(num_iterations):
        grad = f_prime(x_current)  # Gradient (derivative)
        x_current = x_current - learning_rate * grad  # Update step
        x_history.append(x_current)
    
    return x_history

# Parameters
learning_rate = 0.1
num_iterations = 20

# Run Gradient Descent
x_history = gradient_descent(learning_rate, num_iterations)

# Plot the results
x = np.linspace(-10, 10, 400)
y = f(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='$f(x) = x^2$', color='blue')
plt.scatter(x_history, f(np.array(x_history)), color='red', label="Gradient Descent Steps", zorder=5)
plt.title("Gradient Descent to Minimize $f(x) = x^2$")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Integrals give us the area under a curve, and in ML, we often use them to compute areas under probability distributions or total loss.

# %%
from scipy.integrate import quad
a
# Define the function for integration (e.g., x^2)
def f_integral(x):
    return x**2

# Integrate the function from 0 to 3
integral_value, error = quad(f_integral, 0, 3)

# Print the result
print(f"Integral of x^2 from 0 to 3: {integral_value}")
# Out:
# Integral of x^2 from 0 to 3: 9.000000000000002

# %%
# Plotting the function and area under the curve
x = np.linspace(0, 3, 400)
y = f(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='$f(x) = x^2$', color='blue')
plt.fill_between(x, y, where=(x <= 3), color='skyblue', alpha=0.5, label='Area under $f(x)$')
plt.title("Area Under the Curve of $f(x) = x^2$")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
